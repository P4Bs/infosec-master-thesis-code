# %%
import json
import os
import pandas as pd
import re
import torch

from pathlib import Path
from sklearn.metrics import confusion_matrix, classification_report
from tqdm import tqdm
from transformers import pipeline, BitsAndBytesConfig
# Out:
# W0620 14:05:09.662000 24504 venv\Lib\site-packages\torch\utils\_pytree.py:630] <enum 'KernelPreference'> is an Enum subclass and is now natively supported by torch.compile as an opaque value type. Calling register_constant() on Enum subclasses is deprecated and will be an error in a future release.
# W0620 14:05:09.701000 24504 venv\Lib\site-packages\torch\utils\_pytree.py:630] <enum 'ScaleCalculationMode'> is an Enum subclass and is now natively supported by torch.compile as an opaque value type. Calling register_constant() on Enum subclasses is deprecated and will be an error in a future release.

# %%
BATCH_SIZE = 8
MAX_NEW_TOKENS = 20
DO_SAMPLE = False
NUM_BEAMS = 1

PROJECT_PATH = Path(os.getcwd()).parent.parent
DS_PATH = PROJECT_PATH / "datasets" / "fine-tuning" / "conversational"
TESTING_DS_PATH = DS_PATH / "ordered_testing_ds_juliet.jsonl"

OUTPUT_METRICS_PATH = Path(os.getcwd()).parent.parent / "output_metrics"
OUTPUT_METRICS_FILE = OUTPUT_METRICS_PATH / "meta-llama-3_2-1B-fine-tuned.txt"
MODEL_ID = str(Path("~/ft/meta-llama-3_2-1B-instruct/fine-tuned").expanduser())

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_use_double_quant=True,
)

# %%
pipe = pipeline(
    "text-generation",
    model=MODEL_ID,
    device=DEVICE,
    model_kwargs={
        "quantization_config": quantization_config,
        "dtype": torch.bfloat16,
    }
)
# Out:
# Loading weights:   0%|          | 0/146 [00:00<?, ?it/s]
# C:\Users\pablo\Projects\infosec-master-thesis\src\llm\venv\Lib\site-packages\bitsandbytes\backends\cuda\ops.py:213: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Loading weights:   0%|          | 0/64 [00:00<?, ?it/s]

# %%
if pipe.tokenizer.pad_token is None:
    print("WARNING: No pad token defined. Using end of sentence token.")
    pipe.tokenizer.pad_token = pipe.tokenizer.eos_token
# Out:
# WARNING: No pad token defined. Using end of sentence token.

# %%
def extract_prompt(example):
    return example["messages"]

# %%
examples = []
with open(TESTING_DS_PATH, "r", encoding="utf-8") as f:
    for line in f:
        examples.append(json.loads(line.strip()))

first_5K_cases = examples[:5000]

# %%
len(first_5K_cases)
# Out:
# 5000

# %%
generated_texts = []
ground_truths = []

# %%
print(f"Processing {len(first_5K_cases)} examples in batches of size {BATCH_SIZE}...")
## Load in tqdm to see progress bar
for i in tqdm(range(0, len(first_5K_cases), BATCH_SIZE), desc="Procesando"):
    batch_examples = first_5K_cases[i:i + BATCH_SIZE]
    prompts = [extract_prompt(example) for example in batch_examples]
    true_labels = [example.get("cwe", []) for example in batch_examples]

    with torch.no_grad():
        outputs = pipe(
            prompts,
            max_new_tokens=MAX_NEW_TOKENS,
            batch_size=BATCH_SIZE,
            padding=True,
            truncation = True,
            return_full_text=False,
            do_sample=DO_SAMPLE,
            num_beams=NUM_BEAMS,
        )

    for k, (output, true_label) in enumerate(zip(outputs, true_labels)):
        generated = output[0]["generated_text"] if isinstance(output, list) else output["generated_text"]

        generated_clean = generated.strip()
        generated_texts.append(generated_clean)
        ground_truths.append(true_label)
# Out:
# Processing 5000 examples in batches of size 8...
# Procesando:   0%|          | 0/625 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Passing `generation_config` together with generation-related arguments=({'do_sample', 'num_beams', 'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando:   0%|          | 1/625 [00:01<10:36,  1.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando:   0%|          | 2/625 [00:01<07:40,  1.35it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando:   0%|          | 3/625 [00:02<06:33,  1.58it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando:   1%|          | 4/625 [00:02<06:08,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando:
  1.53it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando:  96%|█████████▌| 599/625 [05:55<00:16,  1.53it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando:  96%|█████████▌| 600/625 [05:56<00:16,  1.53it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando:  96%|█████████▌| 601/625 [05:56<00:15,  1.53it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando:  96%|█████████▋| 602/625 [05:57<00:14,  1.53it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando:  96%|█████████▋| 603/625 [05:58<00:14,  1.53it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando:  97%|█████████▋| 604/625 [05:58<00:13,  1.52it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando:  97%|█████████▋| 605/625 [05:59<00:13,  1.53it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando:  97%|█████████▋| 606/625 [06:00<00:12,  1.54it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando:  97%|█████████▋| 607/625 [06:00<00:11,  1.54it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando:  97%|█████████▋| 608/625 [06:01<00:10,  1.55it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando:  97%|█████████▋| 609/625 [06:02<00:10,  1.54it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando:  98%|█████████▊| 610/625 [06:02<00:09,  1.52it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando:  98%|█████████▊| 611/625 [06:03<00:09,  1.53it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando:  98%|█████████▊| 612/625 [06:04<00:08,  1.51it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando:  98%|█████████▊| 613/625 [06:04<00:07,  1.50it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando:  98%|█████████▊| 614/625 [06:05<00:07,  1.53it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando:  98%|█████████▊| 615/625 [06:06<00:06,  1.50it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando:  99%|█████████▊| 616/625 [06:06<00:05,  1.50it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando:  99%|█████████▊| 617/625 [06:07<00:05,  1.53it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando:  99%|█████████▉| 618/625 [06:08<00:04,  1.52it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando:  99%|█████████▉| 619/625 [06:08<00:03,  1.52it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando:  99%|█████████▉| 620/625 [06:09<00:03,  1.53it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando:  99%|█████████▉| 621/625 [06:10<00:02,  1.53it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando: 100%|█████████▉| 622/625 [06:10<00:01,  1.55it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando: 100%|█████████▉| 623/625 [06:11<00:01,  1.55it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando: 100%|█████████▉| 624/625 [06:12<00:00,  1.52it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Procesando: 100%|██████████| 625/625 [06:12<00:00,  1.68it/s]

# %%
regex_cwe = re.compile(r"CWE-\d{1,3}", re.IGNORECASE)
regex_safe = re.compile(r"SAFE", re.IGNORECASE)

predictions = []
for text in generated_texts:
    match_cwe = regex_cwe.search(text)
    if match_cwe:
        predictions.append(match_cwe.group(0))
        continue

    match_safe = regex_safe.search(text)
    if match_safe:
        predictions.append(match_safe.group(0))
        continue

    predictions.append("UNKNOWN")

# %%
valid_mask = [p != "ERROR" and t != "ERROR" for p, t in zip(predictions, ground_truths)]
valid_pred = [p for p, v in zip(predictions, valid_mask) if v]
valid_true = [t for t, v in zip(ground_truths, valid_mask) if v]

labels = sorted(set(valid_true + valid_pred))
print("Etiquetas encontradas:", labels)

cm = confusion_matrix(valid_true, valid_pred)

# CREATE OUTPUT METRICS FILE DIRECTORY
OUTPUT_METRICS_PATH.mkdir(exist_ok=True)
with open(OUTPUT_METRICS_FILE, 'w') as f:
    print("\nConfusion Matrix:", file=f)
    print(pd.DataFrame(cm, index=labels, columns=labels), file=f)

    print("\nClassification Report:", file=f)
    print(classification_report(valid_true, valid_pred), file=f)
# Out:
# Etiquetas encontradas: ['CWE-121', 'CWE-122', 'CWE-123', 'CWE-124', 'CWE-126', 'CWE-127', 'CWE-129', 'CWE-244', 'CWE-401', 'CWE-415', 'CWE-416', 'CWE-476', 'CWE-480', 'CWE-562', 'CWE-590', 'CWE-680', 'CWE-685', 'CWE-688', 'CWE-761', 'CWE-789', 'CWE-835', 'SAFE']
# C:\Users\pablo\Projects\infosec-master-thesis\src\llm\venv\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\pablo\Projects\infosec-master-thesis\src\llm\venv\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\pablo\Projects\infosec-master-thesis\src\llm\venv\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
